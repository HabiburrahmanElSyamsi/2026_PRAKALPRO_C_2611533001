# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Habiburrahman El Syamsi**
#
# **2611533001**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum  Pengenalan Python, VS Code, dan Koneksi ke GitHub yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan pengenalan lingkungan kerja pemrograman Python, pemanfaatan ekstensinya seperti Python Debugger dan Jupyter pada Visual Studio Code, serta mekanisme pengintegrasian repositori lokal ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar sintaksis Python—seperti cetak keluaran (output stream), manipulasi string, dan sintaksis komentar—serta pengelolaan kontrol versi kode pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Di era modern, pemahaman terhadap bahasa pemrograman, tools pengembangan, dan sistem kolaborasi merupakan fondasi utama dalam dunia teknologi. Python menjadi bahasa pemrograman yang sangat penting dipelajari karena sintaksnya yang sederhana, serbaguna, dan digunakan secara luas mulai dari otomatisasi dasar hingga kecerdasan buatan.
#
# Untuk menulis dan menguji kode secara efisien, penggunaan code editor yang handal seperti Visual Studio Code (VS Code) sangat diperlukan. VS Code menyediakan fitur debugging, auto-completion, dan ekstensi yang mempermudah proses pemograman.
#
# Selain penulisan kode, aspek penting lainnya adalah pengelolaan versi dan kolaborasi proyek. Melalui pengintegrasian VS Code ke GitHub (menggunakan Git), pengembang dapat menyimpan riwayat perubahan kode secara terstruktur, mencadangkan proyek di cloud, dan berkolaborasi dalam tim.
#
# Praktikum ini penting dilakukan agar praktikan tidak hanya memahami logika pemrograman dasar dengan Python, tetapi juga menguasai workflow standar industri dalam mengelola dan mendokumentasikan kode program.
#
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemrograman Python serta cara menjalankan skrip program sederhana.
# 2. Menguasai penggunaan Visual Studio Code (VS Code) sebagai lingkungan pengembangan (code editor) dalam menulis dan menguji kode.
# 3. Mampu menghubungkan VS Code ke GitHub untuk mengelola version control dan menyimpan repositori proyek secara online.
#
# ## 1.3 Manfaat
# 1. Meningkatkan Efisiensi Pemrograman: Praktikan mampu menulis dan menguji kode Python lebih cepat dan terstruktur menggunakan fitur-fitur yang ada di VS Code.
# 2. Kesiapan Kolaborasi dan Portofolio: Praktikan memiliki kemampuan mengelola riwayat perubahan kode serta mempublikasikan proyek ke GitHub sebagai portofolio digital.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Tuliskan penjelasan konsep/teori yang mendasari praktikum ini (definisi, elemen-elemen penting, dsb). Bisa memakai poin bernomor untuk merinci sub-konsep, contoh:
#
# 1. Bahasa Pemrograman Python
# Python adalah bahasa pemrograman tingkat tinggi yang bersifat open-source, interpreted, dan berorientasi objek (object-oriented). Python dikenal dengan sintaksnya yang relatif sederhana dan mudah dibaca, sehingga memungkinkan pengembang berfokus pada logika pemecahan masalah dibandingkan kerumitan aturan sintaksis. Dalam konteks praktikum, Python digunakan sebagai bahasa dasar untuk mempelajari logika pemrograman dan mengeksekusi perintah atau skrip.
# 2. Visual Studio Code (VS Code) sebagai Code Editor
# Visual Studio Code adalah Integrated Development Environment (IDE) berbasis teks (code editor) yang ringan namun kaya fitur. VS Code menyediakan berbagai fasilitas pendukung pengembangan perangkat lunak, seperti syntax highlighting, intelliSense (saran kode otomatis), integrated terminal, serta fitur debugging. Penggunaan VS Code membantu mempercepat proses penulisan dan pengujian kode program secara lebih terstruktur.
# 3. Sistem Pengontrol Versi (Git) dan Platform GitHub
# Git adalah sistem pengontrol versi terdistribusi (distributed version control system) yang berfungsi untuk mencatat setiap perubahan pada berkas kode proyek. Sementara itu, GitHub adalah platform berbasis cloud yang meng-host repositori Git. Pengintegrasian VS Code dengan GitHub memungkinkan penyimpanan kode secara aman, pengelolaan riwayat revisi (commit), serta pengerjaan proyek secara kolaboratif dalam tim.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611533001"
# Pengembangan program berbasis Python ini dilakukan melalui Visual Studio Code. Penggunaan Python pada praktikum ini bertujuan untuk membuat dan menjalankan program sederhana guna memahami dasar-dasar sintaksis bahasa python.

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Departemen Informatika")
print("Universitas Andalas")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a\\n" + "Habiburrahman El Syamsi 2611533001")

# %% [markdown]
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program inidibuat oleh a\nHabiburrahman El Syamsi 2611533001

# %% [markdown]
# **Penjelasan :**
# 1. Tanda # digunakan untuk membuat komentar satu baris (single-line comment).
# 2. Tanda """ digunakan untuk membuat komentar multi-baris (multiline comment) atau teks yang berjumlah lebih dari satu baris.
# 3. Fungsi print() digunakan untuk menampilkan data atau teks ke layar console (terminal).
# 4. Tanda + dalam fungsi print digunakan untuk menggabungkan beberapa teks (string concatenation).
# 5. Tanda \\ (escape sequence) digunakan khusus agar karakter backslash bisa ikut tercetak ke layar tanpa memicu kesalahan sistem.
# 6. Program Python ini dapat dieksekusi melalui terminal atau langsung menggunakan fitur Run yang disediakan pada VS Code.

# %% [markdown]
# ### 2.2.2 Program Repository GitHub
# Setelah program dibuat dan diuji pada VS Code, proyek dihubungkan ke platform GitHub. Repositori ini berfungsi untuk menyimpan, mengelola, dan mengamankan berkas kode program secara daring (online).
#
# Tahapan yang dilakukan yaitu:
#
# 1. Membuat repositori baru pada halaman GitHub.
# 2. Membuka folder proyek menggunakan VS Code.
# 3. Membuka terminal terintegrasi pada VS Code.
# 4. Menginisialisasi Git pada folder proyek lokal.
# 5. Menambahkan berkas ke dalam staging area.
# 6. Membuat commit untuk menyimpan riwayat perubahan.
# 7. Menghubungkan repositori lokal dengan repositori di GitHub.
# 8. Melakukan push untuk mengunggah kode ke GitHub.
#
# Contoh perintah (command) yang digunakan pada terminal:

# %%
git init
git add .
git commit -m "Initial commit"
git branch -M main
git remote add origin https://github.com/username/nama-repository.git
git push -u origin main

# %% [markdown]
# 1. git init: Digunakan untuk membuat dan menginisialisasi repositori Git baru pada folder proyek lokal.
# 2. git add .: Digunakan untuk menambahkan seluruh berkas dan perubahan pada proyek ke dalam staging area.
# 3. git commit: Digunakan untuk menyimpan riwayat perubahan dari staging area disertai pesan deskriptif.
# 4. git branch -M main: Digunakan untuk mengubah atau mengonfirmasi nama cabang (branch) utama menjadi main.
# 5. git remote add origin: Digunakan untuk menghubungkan repositori lokal dengan repositori yang telah dibuat di GitHub.
# 6. git push: Digunakan untuk mengunggah berkas dan riwayat commit dari komputer lokal ke repositori GitHub.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# 1. buatlah sebuah file program python bebas dengan nama tugas1_nim.py
# 2. buatlah laporan praktikum pekan 1 ( laporan berisi praktikum dan penjelasan tugas) dengan format file: LapPrak_ALpro1.ipyb
# 3. buatlah tahapan commit dan push file tugas dan laporan tersebut ke akun github masing-masing tutorial template tugas: https://drive.google.com/drive/folders/1347SclkgXMuyAvKBs_YSGFz3fpvs_qul?usp=sharing
# kode program :
#
# a.Kode Program Tugas1_2611533001
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "NamaKelas_NIM"

# %%
print(" _______       /\\   ")
print("|  ___  \\     /  \\  ")
print("| |___| |    / /\\ \\ ")
print("|  ___  <   / ____ \\")
print("| |___| |  /_/    \\_\\")
print("|_______/           ")
# Out:
#  _______       /\
# |  ___  \     /  \
# | |___| |    / /\ \
# |  ___  <   / ____ \
# | |___| |  /_/    \_\
# |_______/

# %% [markdown]
# Penjelasan : Program ini hanya melakukan operasi print() dengan tujuan mencetak logo BA dengan ukuran besar.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa penggunaan bahasa pemrograman Python, editor Visual Studio Code, serta sistem kontrol versi Git dan GitHub berhasil dikuasai sebagai fondasi utama dalam lingkungan pengembangan perangkat lunak.
#
# Dalam konteks pemrograman Python, konsep ini memanfaatkan sintaksis yang sederhana dan ekosistem tools yang terintegrasi (seperti Python Debugger dan Jupyter pada VS Code), serta platform GitHub untuk menyimpan dan mengelola versi kode secara daring, sehingga proses penulisan, pengujian, hingga dokumentasi program dapat dilakukan secara lebih efisien, terstruktur, dan siap untuk pengembangan proyek secara kolaboratif.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1.Chacon, S., & Straub, B. (2014). Pro Git (2nd ed.). Apress.https://git-scm.com/book/en/v2
#
# 2.Kluyver, T., Ragan-Kelley, B., Pérez, F., Granger, B. E., Bussonnier, M., Frederic, J., Fortin, F. A., Slemmer, M., & Willing, C. (2016). Jupyter Notebooks-a publishing format for reproducible computational workflows. Positioning and Power in Academic Publishing: Players, Agents and Agendas, 87-90.https://ebooks.iospress.nl/volumearticle/44158
#
# 3.Microsoft. (2023). Visual Studio Code Documentation: Python in VS Code. Microsoft Docs.https://code.visualstudio.com/docs/python/python-tutorial
#
# 4.Severance, C. R. (2016). Python for Everybody: Exploring Data in Python 3. CreateSpace Independent Publishing Platform.https://www.py4e.com/book
